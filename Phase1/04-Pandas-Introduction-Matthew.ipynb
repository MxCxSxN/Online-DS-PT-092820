# %% [markdown]
# # Importing, Reading and Manipulating Data with ACTUAL LITERAL PANDAS
#
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - but Pandas is a great library to work with relational data.
#
# [Check out the documentation!](https://pandas.pydata.org/pandas-docs/stable/) (always a great idea)

# %% [markdown]
# Before we get into Pandas, let's talk about Numpy for a second. Numpy stands for "Numerical Python" and it's designed for high-level mathematical functions and computing functionality. It uses multi-dimensional arrays to store data, which is more convenient and more optimized than a 'pure' Python type. What that means is that Numpy is fast - faster than base Python.
#
# We're not going to go into a lot of Numpy functionality here, but here's something cool - Pandas is built on top of Numpy! That means they work really well together, and that Pandas has some math functionality already built in.
#
# If you'd like to read more about Numpy and Pandas, [here is an interesting blog post](https://cloudxlab.com/blog/numpy-pandas-introduction/) discussing them.

# %% [markdown]
# Let's dive into some data from the Austin Animal Shelter.
#
# Data source: [intakes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm) and [outcomes data](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238).
#
# Today we'll be working with the intakes data, which I've already downloaded and included in the repository.

# %%
# Import
import pandas as pd

# %%
intakes = pd.read_csv('data/Austin_Animal_Center_Intakes_10-08-20.csv',
                     parse_dates=['DateTime'])
outcomes = pd.read_csv('data/Austin_Animal_Center_Outcomes_10-14-20.csv',
                      parse_dates=['DateTime'])

# %% [markdown]
# Before reading in the data, we need to know what format the data is in and where exactly the data can be found, so we can tell Pandas what to do.

# %%
# Where is our data?
# !ls
# Out:
# 00-Orientation.pdf
# 01-WhatIsDataScience.pdf
# 02-Terminal-Git-Github.pdf
# 03-Python-Loops-and-Functions-Matthew.ipynb
# 04-Pandas-Introduction-Matthew.ipynb
# 05-Pandas-Practice-Matthew.ipynb
# Week1-PythonReview
# Week2-PythonChallenge
# complete-notebooks
# data
# images

# %%
# Read in the comma-separated-value (csv) document as df
#See ABOVE 
#ex. 
# intakes = pd.read_csv('data/Austin_Animal_Center_Intakes_10-08-20.csv')

# %% [markdown]
# What options do we have when we read in a csv? Let's look at the documentation!
#
# [Convenient link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#
# I happen to know that there is a column in the data named 'DateTime' - let's use an argument to read it in as a datetime object, then discuss.

# %% [markdown]
# ### Initial Exploration of a Dataframe
#
# Questions to ask yourself:
#
# - How big is the data?
# - Are there any empty cells?
# - What are the datatypes of the columns of data?

# %%
# What does this dataframe look like?
# Check out the first 5 rows
intakes.head(50)
# Out:
#    Animal ID         Name            DateTime               MonthYear  \
# 0    A786884       *Brock 2019-01-03 16:19:00  01/03/2019 04:19:00 PM
# 1    A706918        Belle 2015-07-05 12:59:00  07/05/2015 12:59:00 PM
# 2    A724273      Runster 2016-04-14 18:43:00  04/14/2016 06:43:00 PM
# 3    A665644          NaN 2013-10-21 07:59:00  10/21/2013 07:59:00 AM
# 4    A682524          Rio 2014-06-29 10:38:00  06/29/2014 10:38:00 AM
# 5    A743852         Odin 2017-02-18 12:46:00  02/18/2017 12:46:00 PM
# 6    A635072      Beowulf 2019-04-16 09:53:00  04/16/2019 09:53:00 AM
# 7    A708452       Mumble 2015-07-30 14:37:00  07/30/2015 02:37:00 PM
# 8    A774147          NaN 2018-06-11 07:45:00  06/11/2018 07:45:00 AM
# 9    A731435       *Casey 2016-08-08 17:52:00  08/08/2016 05:52:00 PM
# 10   A760053          NaN 2017-10-11 15:46:00  10/11/2017 03:46:00 PM
# 11   A707375  *Candy Cane 2015-07-11 18:19:00  07/11/2015 06:19:00 PM
# 12   A696408       *Pearl 2015-02-04 12:58:00  02/04/2015 12:58:00 PM
# 13   A790209        Ziggy 2019-03-06 14:31:00  03/06/2019 02:31:00 PM
# 14   A743114          NaN 2017-02-04 10:10:00  02/04/2017 10:10:00 AM
# 15   A657188        Tommy 2013-11-10 17:19:00  11/10/2013 05:19:00 PM
# 16   A783861        Tulip 2018-11-07 15:53:00  11/07/2018 03:53:00 PM
# 17   A707658        *Mint 2015-07-15 17:43:00  07/15/2015 05:43:00 PM
# 18   A736287    *Twilight 2016-10-08 11:53:00  10/08/2016 11:53:00 AM
# 19   A697950          NaN 2015-03-04 11:22:00  03/04/2015 11:22:00 AM
# 20   A298074       Stumpy 2015-09-06 14:21:00  09/06/2015 02:21:00 PM
# 21   A754715        Rheia 2019-07-29 17:19:00  07/29/2019 05:19:00 PM
# 22   A810994          NaN 2019-12-25 00:05:00  12/25/2019 12:05:00 AM
# 23   A769764          NaN 2018-04-09 19:03:00  04/09/2018 07:03:00 PM
# 24   A707974   *Cleopatra 2015-07-20 18:13:00  07/20/2015 06:13:00 PM
# 25   A682230          NaN 2014-06-25 16:27:00  06/25/2014 04:27:00 PM
# 26   A749436          NaN 2017-05-15 09:50:00  05/15/2017 09:50:00 AM
# 27   A722979          NaN 2016-03-24 16:39:00  03/24/2016 04:39:00 PM
# 28   A803723          NaN 2019-09-05 12:00:00  09/05/2019 12:00:00 PM
# 29   A696205          Roo 2015-02-12 11:57:00  02/12/2015 11:57:00 AM
# 30   A759935        Dieve 2017-10-09 22:39:00  10/09/2017 10:39:00 PM
# 31   A666877       *Romeo 2013-11-08 15:24:00  11/08/2013 03:24:00 PM
# 32   A794334        Pearl 2019-09-02 11:52:00  09/02/2019 11:52:00 AM
# 33   A706507          NaN 2015-06-29 17:04:00  06/29/2015 05:04:00 PM
# 34   A732903       *Raven 2016-08-14 15:02:00  08/14/2016 03:02:00 PM
# 35   A789526       Sixlet 2019-02-23 11:22:00  02/23/2019 11:22:00 AM
# 36   A749400      *Pepper 2017-05-14 14:19:00  05/14/2017 02:19:00 PM
# 37   A727838          NaN 2016-05-26 14:01:00  05/26/2016 02:01:00 PM
# 38   A769816     *Wallace 2018-04-10 16:46:00  04/10/2018 04:46:00 PM
# 39   A701811          NaN 2015-05-05 07:29:00  05/05/2015 07:29:00 AM
# 40   A812244          NaN 2020-01-18 14:14:00  01/18/2020 02:14:00 PM
# 41   A700396      Calseta 2015-12-07 09:11:00  12/07/2015 09:11:00 AM
# 42   A724378        Boxer 2016-04-16 13:36:00  04/16/2016 01:36:00 PM
# 43   A702701       Pepper 2015-05-16 18:38:00  05/16/2015 06:38:00 PM
# 44   A759995          NaN 2017-10-11 11:48:00  10/11/2017 11:48:00 AM
# 45   A702931        Henry 2015-05-19 13:23:00  05/19/2015 01:23:00 PM
# 46   A745133       *Magic 2017-03-13 12:50:00  03/13/2017 12:50:00 PM
# 47   A747817        Annie 2017-04-25 12:02:00  04/25/2017 12:02:00 PM
# 48   A736501       Travis 2016-10-11 16:43:00  10/11/2016 04:43:00 PM
# 49   A755102      Talesin 2017-07-29 11:49:00  07/29/2017 11:49:00 AM
#
#                                       Found Location         Intake Type  \
# 0                2501 Magin Meadow Dr in Austin (TX)               Stray
# 1                   9409 Bluegrass Dr in Austin (TX)               Stray
# 2                 2818 Palomino Trail in Austin (TX)               Stray
# 3                                        Austin (TX)               Stray
# 4                      800 Grove Blvd in Austin (TX)               Stray
# 5                                        Austin (TX)     Owner Surrender
# 6                415 East Mary Street in Austin (TX)       Public Assist
# 7                                        Austin (TX)       Public Assist
# 8                      6600 Elm Creek in Austin (TX)               Stray
# 9                                        Austin (TX)     Owner Surrender
# 10            8800 South First Street in Austin (TX)               Stray
# 11      Galilee Court And Damita Jo Dr in Manor (TX)               Stray
# 12                       9705 Thaxton in Austin (TX)               Stray
# 13                 4424 S Mopac Expwy in Austin (TX)       Public Assist
# 14                      208 Beaver St in Austin (TX)               Stray
# 15                                       Austin (TX)     Owner Surrender
# 16              3110 Guadalupe Street in Austin (TX)               Stray
# 17                       6118 Fairway in Austin (TX)               Stray
# 18           South First And Stassney in Austin (TX)               Stray
# 19                      1501 S Fm 973 in Austin (TX)               Stray
# 20                     1801 Westridge in Austin (TX)               Stray
# 21                                       Austin (TX)     Owner Surrender
# 22                    7900 Rm 1826 Rd in Travis (TX)            Wildlife
# 23           7500 South Interstate 35 in Austin (TX)               Stray
# 24                       2307 Ventura in Austin (TX)               Stray
# 25                      3737 Keats Dr in Austin (TX)               Stray
# 26  East Pleasant Valley And Stassney in Austin (TX)               Stray
# 27                   4100 Westbank Dr in Austin (TX)            Wildlife
# 28               10508 Twilight Vista in Austin (TX)               Stray
# 29                                       Austin (TX)     Owner Surrender
# 30                 4800 Cottonwood St in Austin (TX)               Stray
# 31                Guadalupe/St. Johns in Austin (TX)               Stray
# 32                              Outside Jurisdiction     Owner Surrender
# 33                   5306  Peppertree in Austin (TX)               Stray
# 34                                       Austin (TX)               Stray
# 35               2504 Stratford Drive in Austin (TX)               Stray
# 36                      1834 Ferguson in Austin (TX)               Stray
# 37                   2504 Huntwick Dr in Austin (TX)               Stray
# 38           17833 Basket Flower Bend in Travis (TX)               Stray
# 39                  4434 Frontier Trl in Austin (TX)               Stray
# 40                                       Travis (TX)     Owner Surrender
# 41               4200 Smith School Rd in Austin (TX)               Stray
# 42                                       Austin (TX)     Owner Surrender
# 43         Mcneil Drive & Burnet Road in Austin (TX)               Stray
# 44              1709 East 38Th Street in Austin (TX)               Stray
# 45                                       Austin (TX)  Euthanasia Request
# 46          11699 James B Connolly Ln in Austin (TX)               Stray
# 47               1328 Lamar Square Dr in Austin (TX)               Stray
# 48                                       Austin (TX)     Owner Surrender
# 49           18120 River Timber Drive in Travis (TX)               Stray
#
#    Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0            Normal         Dog   Neutered Male         2 years
# 1            Normal         Dog   Spayed Female         8 years
# 2            Normal         Dog     Intact Male       11 months
# 3              Sick         Cat   Intact Female         4 weeks
# 4            Normal         Dog   Neutered Male         4 years
# 5            Normal         Dog   Neutered Male         2 years
# 6            Normal         Dog   Neutered Male         6 years
# 7            Normal         Dog     Intact Male         2 years
# 8           Injured         Cat   Intact Female         4 weeks
# 9            Normal         Cat   Neutered Male        5 months
# 10           Normal         Dog     Intact Male         2 years
# 11           Normal         Dog   Intact Female        5 months
# 12           Normal         Dog   Intact Female         2 years
# 13           Normal         Cat   Intact Female         4 years
# 14          Injured         Cat   Intact Female         2 years
# 15           Normal         Cat   Neutered Male        14 years
# 16           Normal         Cat   Intact Female         1 month
# 17           Normal         Cat   Intact Female         4 weeks
# 18           Normal         Cat   Intact Female         1 month
# 19           Normal         Dog   Intact Female        2 months
# 20           Normal         Dog   Spayed Female        18 years
# 21           Normal         Dog   Spayed Female         2 years
# 22           Normal       Other         Unknown         2 years
# 23           Normal         Dog   Intact Female        5 months
# 24           Normal         Cat   Intact Female         2 years
# 25           Normal         Dog   Intact Female        5 months
# 26           Normal         Dog     Intact Male        4 months
# 27           Normal       Other         Unknown          1 year
# 28           Normal         Cat         Unknown        6 months
# 29           Normal         Cat   Spayed Female         2 years
# 30           Normal         Dog   Intact Female         1 month
# 31           Normal         Dog     Intact Male          1 year
# 32             Sick         Dog   Spayed Female         3 years
# 33           Normal         Cat         Unknown          4 days
# 34          Injured         Dog   Intact Female        2 months
# 35           Normal         Cat   Intact Female         1 month
# 36           Normal         Cat   Intact Female           1 day
# 37           Normal         Cat   Intact Female         2 years
# 38           Normal         Dog     Intact Male         5 years
# 39          Nursing         Cat         Unknown         2 weeks
# 40           Normal         Dog     Intact Male         1 month
# 41           Normal         Dog   Spayed Female         3 years
# 42           Normal         Dog     Intact Male         4 years
# 43           Normal         Dog   Spayed Female         2 years
# 44           Normal         Cat         Unknown        4 months
# 45             Aged       Other         Unknown         2 years
# 46           Normal         Dog     Intact Male          1 year
# 47           Normal         Cat   Intact Female         2 years
# 48             Sick         Cat   Neutered Male        15 years
# 49           Normal         Cat   Spayed Female         8 years
#
#                                        Breed                Color
# 0                                 Beagle Mix             Tricolor
# 1                   English Springer Spaniel          White/Liver
# 2                                Basenji Mix          Sable/White
# 3                     Domestic Shorthair Mix               Calico
# 4      Doberman Pinsch/Australian Cattle Dog             Tan/Gray
# 5                     Labrador Retriever Mix            Chocolate
# 6                             Great Dane Mix                Black
# 7                     Labrador Retriever Mix          Black/White
# 8                     Domestic Shorthair Mix          Black/White
# 9                     Domestic Shorthair Mix          Cream Tabby
# 10                       Chihuahua Shorthair            White/Tan
# 11                                  Pit Bull          Brown/White
# 12                       Chihuahua Shorthair             Tricolor
# 13                    Domestic Shorthair Mix    Brown Tabby/White
# 14                    Domestic Shorthair Mix          Black/White
# 15                    Domestic Shorthair Mix    Brown Tabby/White
# 16                    Domestic Shorthair Mix          Brown Tabby
# 17                    Domestic Shorthair Mix          Black/White
# 18                    Domestic Shorthair Mix               Torbie
# 19  Australian Cattle Dog/Labrador Retriever            Tan/White
# 20                Parson Russell Terrier Mix          Black/White
# 21                    Labrador Retriever Mix          Black/White
# 22                                       Bat                Brown
# 23                     Yorkshire Terrier Mix          White/Black
# 24                    Domestic Shorthair Mix                 Blue
# 25                               Maltese Mix                White
# 26                             Dachshund Mix          Brown/White
# 27                                   Bat Mix                Brown
# 28                        Domestic Shorthair          Black/White
# 29                    Domestic Shorthair Mix                Black
# 30                    Labrador Retriever Mix                Black
# 31                             Dachshund Mix            Tan/White
# 32                                 Boxer Mix                White
# 33                    Domestic Shorthair Mix                Black
# 34                    Labrador Retriever Mix          Black/White
# 35                    Domestic Shorthair Mix                Black
# 36                    Domestic Shorthair Mix                 Blue
# 37                    Domestic Shorthair Mix                Black
# 38                           Plott Hound Mix  Brown Brindle/White
# 39                    Domestic Shorthair Mix           Gray Tabby
# 40                        Labrador Retriever                  Tan
# 41                              Pit Bull Mix          Black/White
# 42                       Tibetan Spaniel Mix          Black/White
# 43                    Miniature Pinscher Mix      Chocolate/Brown
# 44                    Domestic Shorthair Mix          Brown Tabby
# 45                               Hamster Mix           White/Gray
# 46                   Chihuahua Shorthair Mix                  Tan
# 47                    Domestic Shorthair Mix               Tortie
# 48                    Domestic Shorthair Mix                Black
# 49                     Domestic Longhair Mix               Torbie

# %%
# Check out the shape of the df
intakes.shape
# Out:
# (121051, 12)

# %%
# And then the size
intakes.size
# Out:
# 1452612

# %%
# And then look at some info on the df
intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121051 entries, 0 to 121050
# Data columns (total 12 columns):
# Animal ID           121051 non-null object
# Name                82843 non-null object
# DateTime            121051 non-null datetime64[ns]
# MonthYear           121051 non-null object
# Found Location      121051 non-null object
# Intake Type         121051 non-null object
# Intake Condition    121051 non-null object
# Animal Type         121051 non-null object
# Sex upon Intake     121050 non-null object
# Age upon Intake     121051 non-null object
# Breed               121051 non-null object
# Color               121051 non-null object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.1+ MB

# %%
# Describe the columns
intakes.describe()
# Out:
#        Animal ID   Name             DateTime               MonthYear  \
# count     121051  82843               121051                  121051
# unique    108222  19359                85336                   85336
# top      A721033    Max  2016-09-23 12:00:00  09/23/2016 12:00:00 PM
# freq          33    548                   64                      64
# first        NaN    NaN  2013-10-01 07:51:00                     NaN
# last         NaN    NaN  2020-10-05 22:48:00                     NaN
#
#        Found Location Intake Type Intake Condition Animal Type  \
# count          121051      121051           121051      121051
# unique          52519           6               10           5
# top       Austin (TX)       Stray           Normal         Dog
# freq            22227       84625           105629       68571
# first             NaN         NaN              NaN         NaN
# last              NaN         NaN              NaN         NaN
#
#        Sex upon Intake Age upon Intake                   Breed        Color
# count           121050          121051                  121051       121051
# unique               5              51                    2597          587
# top        Intact Male          1 year  Domestic Shorthair Mix  Black/White
# freq             39184           21295                   30770        12679
# first              NaN             NaN                     NaN          NaN
# last               NaN             NaN                     NaN          NaN

# %% [markdown]
# **A note on `.describe()`:** this function behaves differently whether we feed in objects or numeric types. We'll explore this more later.
#
# **And a question:** You see that some of the ways we dealt with our dataframe required `()` and some did not - why is that?
#
# - Why do some have () and others don't?
#     - Functions take arguments *have methods that are associated with the dataframe* () *something you can put arguments into*
#     - The ones that don't have () are attributes. They are simply sttributes of the dataframe, *info about the dataframe*

# %% [markdown]
# ### Accessing Columns
#
# Use brackets and the exact column name to access a particular column.

# %%
# Access specific columns here
type(intakes['Color'])
type(intakes)
intakes[['Color']] #turn it into a DataFrame prove with type([['col_name']])
                   #Can run arguments off of this too!
# Out:
#               Color
# 0          Tricolor
# 1       White/Liver
# 2       Sable/White
# 3            Calico
# 4          Tan/Gray
# ...             ...
# 121046        Black
# 121047   Fawn/White
# 121048  Brown/White
# 121049   Gray/White
# 121050  White/White
#
# [121051 rows x 1 columns]

# %%
intakes.Found Location #Will not work...why?
#Can use this method of accessing columns as long
#as the column name is one word
#Can fix this by updating column names
# Out:
#   File "<ipython-input-38-d8c98ba7ca0d>", line 1
#     intakes.Found Location #Will not work...why?
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Dealing with Datetime Objects
#
# You can access parts of a datetime object using `.dt` - an attribute of the column, not a method!

# %%
# Let's check out the intake year, then other aspects of the date
intakes['DateTime'].dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f176c6feafff> in <module>()
#       1 # Let's check out the intake year, then other aspects of the date
# ----> 2 intakes['DateTime'] = intakes['DateTime'].dt.year
#
# NameError: name 'intakes' is not defined

# %%
#Can run methods on a column
intakes['Name'].str.lower()
# Out:
# 0          *brock
# 1           belle
# 2         runster
# 3             NaN
# 4             rio
#            ...
# 121046        NaN
# 121047    duchess
# 121048        NaN
# 121049        NaN
# 121050      rocky
# Name: Name, Length: 121051, dtype: object

# %%
# How do we create a new column?
# Let's create a new column for intake year
intakes['Intake Year'] = intakes['DateTime'].dt.year

# %%
# Check our work
intakes.head()
# Out:
#   Animal ID     Name            DateTime               MonthYear  \
# 0   A786884   *Brock 2019-01-03 16:19:00  01/03/2019 04:19:00 PM
# 1   A706918    Belle 2015-07-05 12:59:00  07/05/2015 12:59:00 PM
# 2   A724273  Runster 2016-04-14 18:43:00  04/14/2016 06:43:00 PM
# 3   A665644      NaN 2013-10-21 07:59:00  10/21/2013 07:59:00 AM
# 4   A682524      Rio 2014-06-29 10:38:00  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color  Intake Year
# 0                             Beagle Mix     Tricolor         2019
# 1               English Springer Spaniel  White/Liver         2015
# 2                            Basenji Mix  Sable/White         2016
# 3                 Domestic Shorthair Mix       Calico         2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2014

# %%
# What datatype is the data in our new column?
intakes[['Intake Year']].describe()
#Using this for describe will show you median (50%) and mean can also use
# .mean()
intake_year_desc = intakes[['Intake Year']].describe()

# %%
intake_year_desc.iloc[7]
intake_year_desc.index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %% [markdown]
# ### Checking for Null Values
#
# Can use `.isna` or `.isnull` - same thing!

# %%
# Check it - is the result what you expect?
intakes.isna()
# Out:
#         Animal ID   Name  DateTime  MonthYear  Found Location  Intake Type  \
# 0           False  False     False      False           False        False
# 1           False  False     False      False           False        False
# 2           False  False     False      False           False        False
# 3           False   True     False      False           False        False
# 4           False  False     False      False           False        False
# ...           ...    ...       ...        ...             ...          ...
# 121046      False   True     False      False           False        False
# 121047      False  False     False      False           False        False
# 121048      False   True     False      False           False        False
# 121049      False   True     False      False           False        False
# 121050      False  False     False      False           False        False
#
#         Intake Condition  Animal Type  Sex upon Intake  Age upon Intake  \
# 0                  False        False            False            False
# 1                  False        False            False            False
# 2                  False        False            False            False
# 3                  False        False            False            False
# 4                  False        False            False            False
# ...                  ...          ...              ...              ...
# 121046             False        False            False            False
# 121047             False        False            False            False
# 121048             False        False            False            False
# 121049             False        False            False            False
# 121050             False        False            False            False
#
#         Breed  Color  Intake Year
# 0       False  False        False
# 1       False  False        False
# 2       False  False        False
# 3       False  False        False
# 4       False  False        False
# ...       ...    ...          ...
# 121046  False  False        False
# 121047  False  False        False
# 121048  False  False        False
# 121049  False  False        False
# 121050  False  False        False
#
# [121051 rows x 13 columns]

# %%
# How can you make that result more usable?
intakes.isna().sum()
#True = 1 and False = 0. This will show us how many are actually null values
# Out:
# Animal ID               0
# Name                38208
# DateTime                0
# MonthYear               0
# Found Location          0
# Intake Type             0
# Intake Condition        0
# Animal Type             0
# Sex upon Intake         1
# Age upon Intake         0
# Breed                   0
# Color                   0
# Intake Year             0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicate Rows

# %%
# Function is called duplicated - check the documentation!
intakes.isna().sum()

# %%
null_names = intakes['Name'].isna().sum()

# %%
total_rows = len(intakes)

# %%
null_names/total_rows
# Out:
# 0.31563555856622416

# %%
intakes['Name'].isna().mean() #% of null (proof above)
# Out:
# 0.31563555856622416

# %%
# Can use same trick as above on duplicated
intakes.duplicated(keep = False).sum
# Out:
# <bound method Series.sum of 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 121046    False
# 121047    False
# 121048    False
# 121049    False
# 121050    False
# Length: 121051, dtype: bool>

# %% [markdown]
# ### Dropping Columns or Rows
#
# Several different methods depending on what we're doing - but the to discuss right now is `.drop`

# %%
# Let's drop the MonthYear column, which is the same as our DateTime
intakes.drop(columns='MonthYear')
# Out:
#        Animal ID     Name            DateTime  \
# 0        A786884   *Brock 2019-01-03 16:19:00
# 1        A706918    Belle 2015-07-05 12:59:00
# 2        A724273  Runster 2016-04-14 18:43:00
# 3        A665644      NaN 2013-10-21 07:59:00
# 4        A682524      Rio 2014-06-29 10:38:00
# ...          ...      ...                 ...
# 121046   A824073      NaN 2020-10-05 17:05:00
# 121047   A824076  Duchess 2020-10-05 17:28:00
# 121048   A824083      NaN 2020-10-05 20:57:00
# 121049   A824084      NaN 2020-10-05 20:57:00
# 121050   A764365    Rocky 2020-10-05 22:48:00
#
#                              Found Location      Intake Type Intake Condition  \
# 0       2501 Magin Meadow Dr in Austin (TX)            Stray           Normal
# 1          9409 Bluegrass Dr in Austin (TX)            Stray           Normal
# 2        2818 Palomino Trail in Austin (TX)            Stray           Normal
# 3                               Austin (TX)            Stray             Sick
# 4             800 Grove Blvd in Austin (TX)            Stray           Normal
# ...                                     ...              ...              ...
# 121046                           Manor (TX)  Owner Surrender           Normal
# 121047                           Manor (TX)  Owner Surrender          Injured
# 121048         4400 Avenue A in Austin (TX)    Public Assist           Normal
# 121049         4400 Avenue A in Austin (TX)    Public Assist           Normal
# 121050      1005 Glazier Cir in Austin (TX)            Stray           Normal
#
#        Animal Type Sex upon Intake Age upon Intake  \
# 0              Dog   Neutered Male         2 years
# 1              Dog   Spayed Female         8 years
# 2              Dog     Intact Male       11 months
# 3              Cat   Intact Female         4 weeks
# 4              Dog   Neutered Male         4 years
# ...            ...             ...             ...
# 121046         Cat     Intact Male          1 year
# 121047         Dog   Intact Female         5 years
# 121048         Dog         Unknown         2 years
# 121049         Dog         Unknown         2 years
# 121050         Dog     Intact Male         4 years
#
#                                         Breed        Color  Intake Year
# 0                                  Beagle Mix     Tricolor         2019
# 1                    English Springer Spaniel  White/Liver         2015
# 2                                 Basenji Mix  Sable/White         2016
# 3                      Domestic Shorthair Mix       Calico         2013
# 4       Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2014
# ...                                       ...          ...          ...
# 121046                     Domestic Shorthair        Black         2020
# 121047                               Pit Bull   Fawn/White         2020
# 121048                               Pit Bull  Brown/White         2020
# 121049                               Pit Bull   Gray/White         2020
# 121050                            Maltese Mix  White/White         2020
#
# [121051 rows x 12 columns]

# %%
# Check our work here...
intakes.head()
#won't save without you telling it to (rename the dataframe)
# Out:
#   Animal ID     Name            DateTime                       Found Location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    Breed        Color  Intake Year
# 0                             Beagle Mix     Tricolor         2019
# 1               English Springer Spaniel  White/Liver         2015
# 2                            Basenji Mix  Sable/White         2016
# 3                 Domestic Shorthair Mix       Calico         2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2014

# %%
intakes = intakes.drop(columns='MonthYear') 
#or intakes.drop(columns='MonthYear', inplace=True) 
#but this could have memory issues with larger datasets

# %% [markdown]
# Why won't my changes save ???
#
# Fun thing about pandas - time to discuss resetting variables, or using `inplace`

# %% [markdown]
# ### Renaming Columns
#
# [Documentation for `.rename`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html)

# %%
# Let's remove spaces from the columns, and make all column names lowercase to be easier
intakes.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'Found Location', 'Intake Type',
#        'Intake Condition', 'Animal Type', 'Sex upon Intake', 'Age upon Intake',
#        'Breed', 'Color', 'Intake Year'],
#       dtype='object')

# %%
# Can use a dictionary to rename

# %%
# Check your work
list(intakes.columns)
# Out:
# ['Animal ID',
#  'Name',
#  'DateTime',
#  'Found Location',
#  'Intake Type',
#  'Intake Condition',
#  'Animal Type',
#  'Sex upon Intake',
#  'Age upon Intake',
#  'Breed',
#  'Color',
#  'Intake Year']

# %%
# Can also use a lambda function
intakes = intakes.rename(columns = lambda x: x.lower().replace(" ", "_"))

# %% [markdown]
# ### Slicing and Dicing
#
# Perhaps your biggest tool for exploring around your dataframes will be `.loc` (and it's accompanying `.iloc`). This allows you to use conditionals to explore your data!

# %%
# Example: look only at animals with intake type 'Stray'
intakes.loc[intakes['intake_type'] == 'Stray'].head()
# Out:
#   animal_id     name            datetime                       found_location  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2501 Magin Meadow Dr in Austin (TX)
# 1   A706918    Belle 2015-07-05 12:59:00     9409 Bluegrass Dr in Austin (TX)
# 2   A724273  Runster 2016-04-14 18:43:00   2818 Palomino Trail in Austin (TX)
# 3   A665644      NaN 2013-10-21 07:59:00                          Austin (TX)
# 4   A682524      Rio 2014-06-29 10:38:00        800 Grove Blvd in Austin (TX)
#
#   intake_type intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0       Stray           Normal         Dog   Neutered Male         2 years
# 1       Stray           Normal         Dog   Spayed Female         8 years
# 2       Stray           Normal         Dog     Intact Male       11 months
# 3       Stray             Sick         Cat   Intact Female         4 weeks
# 4       Stray           Normal         Dog   Neutered Male         4 years
#
#                                    breed        color  intake_year
# 0                             Beagle Mix     Tricolor         2019
# 1               English Springer Spaniel  White/Liver         2015
# 2                            Basenji Mix  Sable/White         2016
# 3                 Domestic Shorthair Mix       Calico         2013
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray         2014

# %%
# Second example: animals where the animal type is not dog
intakes.loc[intakes['animal_type'] != 'Dog'].head()
# Out:
#    animal_id    name            datetime                     found_location  \
# 3    A665644     NaN 2013-10-21 07:59:00                        Austin (TX)
# 8    A774147     NaN 2018-06-11 07:45:00      6600 Elm Creek in Austin (TX)
# 9    A731435  *Casey 2016-08-08 17:52:00                        Austin (TX)
# 13   A790209   Ziggy 2019-03-06 14:31:00  4424 S Mopac Expwy in Austin (TX)
# 14   A743114     NaN 2017-02-04 10:10:00       208 Beaver St in Austin (TX)
#
#         intake_type intake_condition animal_type sex_upon_intake  \
# 3             Stray             Sick         Cat   Intact Female
# 8             Stray          Injured         Cat   Intact Female
# 9   Owner Surrender           Normal         Cat   Neutered Male
# 13    Public Assist           Normal         Cat   Intact Female
# 14            Stray          Injured         Cat   Intact Female
#
#    age_upon_intake                   breed              color  intake_year
# 3          4 weeks  Domestic Shorthair Mix             Calico         2013
# 8          4 weeks  Domestic Shorthair Mix        Black/White         2018
# 9         5 months  Domestic Shorthair Mix        Cream Tabby         2016
# 13         4 years  Domestic Shorthair Mix  Brown Tabby/White         2019
# 14         2 years  Domestic Shorthair Mix        Black/White         2017

# %%
# And a third - animals found before 2018
intakes.loc[intakes.intake_year > 2018]
# Out:
#        animal_id     name            datetime  \
# 0        A786884   *Brock 2019-01-03 16:19:00
# 6        A635072  Beowulf 2019-04-16 09:53:00
# 13       A790209    Ziggy 2019-03-06 14:31:00
# 21       A754715    Rheia 2019-07-29 17:19:00
# 22       A810994      NaN 2019-12-25 00:05:00
# ...          ...      ...                 ...
# 121046   A824073      NaN 2020-10-05 17:05:00
# 121047   A824076  Duchess 2020-10-05 17:28:00
# 121048   A824083      NaN 2020-10-05 20:57:00
# 121049   A824084      NaN 2020-10-05 20:57:00
# 121050   A764365    Rocky 2020-10-05 22:48:00
#
#                              found_location      intake_type intake_condition  \
# 0       2501 Magin Meadow Dr in Austin (TX)            Stray           Normal
# 6       415 East Mary Street in Austin (TX)    Public Assist           Normal
# 13        4424 S Mopac Expwy in Austin (TX)    Public Assist           Normal
# 21                              Austin (TX)  Owner Surrender           Normal
# 22           7900 Rm 1826 Rd in Travis (TX)         Wildlife           Normal
# ...                                     ...              ...              ...
# 121046                           Manor (TX)  Owner Surrender           Normal
# 121047                           Manor (TX)  Owner Surrender          Injured
# 121048         4400 Avenue A in Austin (TX)    Public Assist           Normal
# 121049         4400 Avenue A in Austin (TX)    Public Assist           Normal
# 121050      1005 Glazier Cir in Austin (TX)            Stray           Normal
#
#        animal_type sex_upon_intake age_upon_intake                   breed  \
# 0              Dog   Neutered Male         2 years              Beagle Mix
# 6              Dog   Neutered Male         6 years          Great Dane Mix
# 13             Cat   Intact Female         4 years  Domestic Shorthair Mix
# 21             Dog   Spayed Female         2 years  Labrador Retriever Mix
# 22           Other         Unknown         2 years                     Bat
# ...            ...             ...             ...                     ...
# 121046         Cat     Intact Male          1 year      Domestic Shorthair
# 121047         Dog   Intact Female         5 years                Pit Bull
# 121048         Dog         Unknown         2 years                Pit Bull
# 121049         Dog         Unknown         2 years                Pit Bull
# 121050         Dog     Intact Male         4 years             Maltese Mix
#
#                     color  intake_year
# 0                Tricolor         2019
# 6                   Black         2019
# 13      Brown Tabby/White         2019
# 21            Black/White         2019
# 22                  Brown         2019
# ...                   ...          ...
# 121046              Black         2020
# 121047         Fawn/White         2020
# 121048        Brown/White         2020
# 121049         Gray/White         2020
# 121050        White/White         2020
#
# [27282 rows x 12 columns]

# %% [markdown]
# ## Let's Start to Answer Questions!

# %% [markdown]
# #### Question 1: What is the most common Animal Type?

# %%
# Let's explore the Animal Type column to find out
def most_frequent(List): 
    counter = 0
    num = List[] 
      
    for i in List.items():
        for key, value in i:
            value = List.count(i) 
            if(curr_frequency> counter): 
            counter = curr_frequency 
            num = i 
  
    return num
# Out:
#   File "<ipython-input-111-08fd04836ef1>", line 4
#     num = List[]
#                ^
# SyntaxError: invalid syntax

# %%
most_frequent(intakes['animal_type'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-5cb3255151cd> in <module>()
# ----> 1 most_frequent(intakes['animal_type'])
#
# <ipython-input-105-6814edb2313c> in most_frequent(List)
#       5
#       6     for i in List:
# ----> 7         curr_frequency = List.count(i)
#       8         if(curr_frequency> counter):
#       9             counter = curr_frequency
#
# /Users/matthewnykaza/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py in count(self, level)
#    1893
#    1894         if isinstance(level, str):
# -> 1895             level = self.index._get_level_number(level)
#    1896
#    1897         lev = self.index.levels[level]
#
# /Users/matthewnykaza/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1561
#    1562     def _get_level_number(self, level):
# -> 1563         self._validate_index_level(level)
#    1564         return 0
#    1565
#
# /Users/matthewnykaza/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1556             raise KeyError(
#    1557                 "Requested level ({}) does not match index name ({})".format(
# -> 1558                     level, self.name
#    1559                 )
#    1560             )
#
# KeyError: 'Requested level (Dog) does not match index name (None)'

# %%
# Another way - look above at describe, or run another describe
# 'Top' for an object column means 'most common'
intakes.animal_type.describe()

# %% [markdown]
# #### Question 2: What is the most common dog breed to come into the shelter?

# %%
# Let's create a new df, dogs, for all dogs in the original data
dog_df = intakes.loc[intakes.animal_type == 'Dog']

# %%
dog_df.breed.describe()
# Out:
# count            68571
# unique            2296
# top       Pit Bull Mix
# freq              8311
# Name: breed, dtype: object

# %%
# Now it's easier to look at common dog breeds
top_dog = dog_df['breed'].describe()[3]

# %%
top_dog
# Out:
# 8311

# %% [markdown]
# #### Question 3: What percentage of animals have come into the shelter in a condition other than "Normal"?

# %%
df = df.groupby('domain')['ID'].nunique()

# %%
# Need to explore the proper column
intakes.intake_condition.nunique()
intakes.groupby(intakes.intake_condition).nunique()
# Out:
#                   animal_id   name  datetime  found_location  intake_type  \
# intake_condition
# Aged                    410    328       383             271            5
# Behavior                 10     10        10              10            3
# Feral                   106     38        74              70            4
# Injured                6282   2373      5909            5150            6
# Medical                  48     36        44              35            3
# Normal                93846  18177     74265           44963            6
# Nursing                3385    934      1009             768            5
# Other                   223    152       150             134            5
# Pregnant                 76     44        70              58            3
# Sick                   4833   1503      4184            3268            6
#
#                   intake_condition  animal_type  sex_upon_intake  \
# intake_condition
# Aged                             1            3                5
# Behavior                         1            1                3
# Feral                            1            3                5
# Injured                          1            4                5
# Medical                          1            2                4
# Normal                           1            5                5
# Nursing                          1            3                5
# Other                            1            4                5
# Pregnant                         1            2                3
# Sick                             1            4                5
#
#                   age_upon_intake  breed  color  intake_year
# intake_condition
# Aged                           21    134     86            8
# Behavior                        5     10     10            2
# Feral                          17     15     35            8
# Injured                        45    552    249            8
# Medical                        18     26     20            2
# Normal                         49   2499    543            8
# Nursing                        31    134    145            8
# Other                          35     70     68            8
# Pregnant                       11     39     34            8
# Sick                           44    336    205            8

# %%
# Want to use pandas to calculate, not inputting number manually

# %%
# Calculate percentage

# %%
# Other way to calculate

# %% [markdown]
# ## Now - Outtake Data!
#
# Let's explore together if we have time! If not - extra credit!
